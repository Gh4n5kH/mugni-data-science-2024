# %% [markdown]
# <a href="https://colab.research.google.com/github/Gh4n5kH/mugni-data-science-2024/blob/main/cont.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Membuat DataFrame dari dictionary
data = {
    'nama': ['Ali', 'Budi', 'Caca', 'Dina'],
    'usia': [22, 25, 21, 23],
    'kota': ['Jakarta', 'Bandung', 'Surabaya', 'Medan'],
    'ipk' : [3.8, 3.5, 3.9, 3.7]
}
df_latihan = pd.DataFrame(data)

# Cek informasi dasar DataFrame
print(df_latihan.shape)    # jumlah baris & kolom
print(df_latihan.dtypes)   # tipe data tiap kolom
print(df_latihan.columns)  # nama kolom
df_latihan
# Out:
# (4, 4)
# nama     object
# usia      int64
# kota     object
# ipk     float64
# dtype: object
# Index(['nama', 'usia', 'kota', 'ipk'], dtype='object')
#    nama  usia      kota  ipk
# 0   Ali    22   Jakarta  3.8
# 1  Budi    25   Bandung  3.5
# 2  Caca    21  Surabaya  3.9
# 3  Dina    23     Medan  3.7
