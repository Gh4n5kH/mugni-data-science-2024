# %% [markdown]
# <a href="https://colab.research.google.com/github/Gh4n5kH/mugni-data-science-2024/blob/main/Pertemuan1_Mugni_240401010355.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")

# SEL 2: Variabel & tipe data
nama = "Mugni"
angkatan = 2024
print(f"Halo, {nama} angkatan {angkatan}!")

# SEL 3: List & perulangan
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")

# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Mugni","Informatika",2024))
# Out:
# Hello, Data Science!
# Halo, Mugni angkatan 2024!
#  1. Python
#  2. Colab
#  3. Jupyter
#  4. GitHub
# Mugni | Informatika | 2024
